# %% [markdown]
# #### 라이브러리 정의

# %%
# - 데이터를 읽기 위한 라이브러리
import pandas as pd

# - 파이썬에서 사용되는 기본 시각화 라이브러리
import matplotlib.pyplot as plt

import numpy as np
from sklearn.cluster import KMeans
import requests
import time
import io

from scipy.interpolate import RBFInterpolator

from math import radians, sin, cos, sqrt, atan2

### 경고(오류는 아님) 메시지 없애기
# - 사이킷런 버전에 따라 오류가 아니니 안내(경고)메시지가 자주 나타남
# - 안내(경고) 메시지 없이 실행할 수 있도록 처리
from sklearn import set_config
set_config(display="text")

# - 한글처리
plt.rc("font", family="Malgun Gothic")

# - 마이너스 기호 깨짐 처리
plt.rcParams["axes.unicode_minus"] = False

# %% [markdown]
# #### 기상 데이터 수집

# %%
# 사우스웨일스주 경계 좌표
lat_range = (-37.5, -29.0)
lon_range = (150.0, 159.0)

# 0.1도 간격 격자 생성 (약 10km)
lat_points = np.arange(lat_range[0], lat_range[1], 0.1)
lon_points = np.arange(lon_range[0], lon_range[1], 0.1)
grid = [(lat, lon) for lat in lat_points for lon in lon_points]
grid_df = pd.DataFrame(grid, columns=["latitude", "longitude"])

# K-Means 클러스터링: 캘리포니아 좌표를 50개의 대표 좌표로 압축
# 목적: API 요청 횟수를 줄이고 데이터 크기를 줄이면서 지역적 대표성을 유지
kmeans = KMeans(n_clusters=50, random_state=42)
grid_df["cluster"] = kmeans.fit_predict(grid_df[["latitude", "longitude"]])
cluster_centers = pd.DataFrame(kmeans.cluster_centers_, columns=["latitude", "longitude"])

# 클러스터링 결과 확인
print("클러스터 중심 좌표 (50개 대표 좌표):")
print(cluster_centers.head())

# 클러스터 중심에서 기상 데이터 수집
start_date = "20150101"
end_date = "20250228"

def get_skiprows(response_text):
    lines = response_text.splitlines()
    skiprows = 0
    for line in lines:
        if line.strip() == "YEAR,DOY,T2M,WS2M,RH2M,PRECTOTCORR":
            break
        skiprows += 1
    return skiprows

def get_weather_data(latitude, longitude):
    url = f"https://power.larc.nasa.gov/api/temporal/daily/point?parameters=T2M,WS2M,RH2M,PRECTOTCORR&community=AG&longitude={longitude}&latitude={latitude}&start={start_date}&end={end_date}&format=CSV"
    try:
        response = requests.get(url, timeout=10)
        response.raise_for_status()
        if response.status_code == 200:
            # 응답 데이터 구조 확인 (디버깅용)
            print(f"응답 데이터 상단 15줄 (위도: {latitude}, 경도: {longitude}):")
            print("\n".join(response.text.splitlines()[:15]))
            # 동적으로 skiprows 계산
            skiprows = get_skiprows(response.text)
            return pd.read_csv(io.StringIO(response.text), skiprows=skiprows, header=0)
        else:
            print(f"데이터 요청 실패! 상태 코드: {response.status_code}, 위도: {latitude}, 경도: {longitude}")
            return None
    except requests.exceptions.RequestException as e:
        print(f"요청 오류 발생: {e}, 위도: {latitude}, 경도: {longitude}")
        return None

weather_data_list = []
for idx, row in cluster_centers.iterrows():
    print(f"요청 중: 클러스터 {idx} (위도 {row['latitude']}, 경도 {row['longitude']})")
    weather_data = get_weather_data(row["latitude"], row["longitude"])
    if weather_data is not None:
        weather_data["latitude"] = row["latitude"]
        weather_data["longitude"] = row["longitude"]
        weather_data_list.append(weather_data)
    time.sleep(5)  # API 요청 간 대기

# 데이터프레임 병합
weather_df = pd.concat(weather_data_list, ignore_index=True)

# acq_date 생성
weather_df["acq_date"] = pd.to_datetime(weather_df["YEAR"].astype(str) + weather_df["DOY"].astype(str), format="%Y%j")

# 결과 출력
print("\n기상 데이터 정보:")
print(weather_df.info())
print(weather_df.head(5))

# 저장
weather_df.to_csv("./data/csv/weather_data.csv", index=False)
# Out:
# 클러스터 중심 좌표 (50개 대표 좌표):
#     latitude   longitude
# 0 -34.292105  157.235526
# 1 -30.899237  153.514504
# 2 -36.982069  154.067586
# 3 -29.597076  155.324561
# 4 -35.598052  151.117532
# 요청 중: 클러스터 0 (위도 -34.29210526315785, 경도 157.23552631578906)
# 응답 데이터 상단 15줄 (위도: -34.29210526315785, 경도: 157.23552631578906):
# -BEGIN HEADER-
# NASA/POWER Source Native Resolution Daily Data
# Dates (month/day/year): 01/01/2015 through 02/28/2025 in LST
# Location: latitude  -34.2921   longitude 157.2355
# elevation from MERRA-2: Average for 0.5 x 0.625 degree lat/lon region = 0.0 meters
# The value for missing source data that cannot be computed or is outside of the sources availability range: -999
# parameter(s):
# T2M             MERRA-2 Temperature at 2 Meters (C)
# WS2M            MERRA-2 Wind Speed at 2 Meters (m/s)
# RH2M            MERRA-2 Relative Humidity at 2 Meters (%)
# PRECTOTCORR     MERRA-2 Precipitation Corrected (mm/day)
# -END HEADER-
# YEAR,DOY,T2M,WS2M,RH2M,PRECTOTCORR
# 2015,1,21.95,4.15,71.47,0.03
# 2015,2,22.51,4.82,78.88,0.55
# 요청 중: 클러스터 1 (위도 -30.899236641221282, 경도 153.5145038167937)
# 응답 데이터 상단 15줄 (위도: -30.899236641221282, 경도: 153.5145038167937):
# -BEGIN HEADER-
# NASA/POWER Source Native Resolution Daily Data
# Dates (month/day/year): 01/01/2015 through 02/28/2025 in LST
# Location: latitude  -30.8992   longitude 153.5145
# elevation from MERRA-2: Average for 0.5 x 0.625 degree lat/lon region = 0.02 meters
# The value for missing source data that cannot be computed or is outside of the sources availability range: -999
# parameter(s):
# T2M             MERRA-2 Temperature at 2 Meters (C)
# WS2M            MERRA-2 Wind Speed at 2 Meters (m/s)
# RH2M            MERRA-2 Relative Humidity at 2 Meters (%)
# PRECTOTCORR     MERRA-2 Precipitation Corrected (mm/day)
# -END HEADER-
# YEAR,DOY,T2M,WS2M,RH2M,PRECTOTCORR
# 2015,1,24.93,6.15,85.91,2.06
# 2015,2,25.27,6.21,86.52,4.44
# 요청 중: 클러스터 2 (위도 -36.982068965517236, 경도 154.06758620689632)
# 응답 데이터 상단 15줄 (위도: -36.982068965517236, 경도: 154.06758620689632):
# -BEGIN HEADER-
# NASA/POWER Source Native Resolution Daily Data
# Dates (month/day/year): 01/01/2015 through 02/28/2025 in LST
# Location: latitude  -36.9821   longitude 154.0676
# elevation from MERRA-2: Average for 0.5 x 0.625 degree lat/lon region = 0.0 meters
# The value for missing source data that cannot be computed or is outside of the sources availability range: -999
# parameter(s):
# T2M             MERRA-2 Temperature at 2 Meters (C)
# WS2M            MERRA-2 Wind Speed at 2 Meters (m/s)
# RH2M            MERRA-2 Relative Humidity at 2 Meters (%)
# PRECTOTCORR     MERRA-2 Precipitation Corrected (mm/day)
# -END HEADER-
# YEAR,DOY,T2M,WS2M,RH2M,PRECTOTCORR
# 2015,1,20.74,5.2,83.77,1.11
# 2015,2,21.64,5.3,94.12,7.95
# 요청 중: 클러스터 3 (위도 -29.597076023391697, 경도 155.32456140350848)
# 응답 데이터 상단 15줄 (위도: -29.597076023391697, 경도: 155.32456140350848):
# -BEGIN HEADER-
# NASA/POWER Source Native Resolution Daily Data
# Dates (month/day/year): 01/01/2015 through 02/28/2025 in LST
# Location: latitude  -29.5971   longitude 155.3246
# elevation from MERRA-2: Average for 0.5 x 0.625 degree lat/lon region = 0.0 meters
# The value for missing source data that cannot be computed or is outside of the sources availability range: -999
# parameter(s):
# T2M             MERRA-2 Temperature at 2 Meters (C)
# WS2M            MERRA-2 Wind Speed at 2 Meters (m/s)
# RH2M            MERRA-2 Relative Humidity at 2 Meters (%)
# PRECTOTCORR     MERRA-2 Precipitation Corrected (mm/day)
# -END HEADER-
# YEAR,DOY,T2M,WS2M,RH2M,PRECTOTCORR
# 2015,1,24.67,5.38,88.37,4.0
# 2015,2,24.47,4.83,85.75,1.72
# 요청 중: 클러스터 4 (위도 -35.59805194805192, 경도 151.1175324675324)
# 응답 데이터 상단 15줄 (위도: -35.59805194805192, 경도: 151.1175324675324):
# -BEGIN HEADER-
# NASA/POWER Source Native Resolution Daily Data
# Dates (month/day/year): 01/01/2015 through 02/28/2025 in LST
# Location: latitude  -35.5981   longitude 151.1175
# elevation from MERRA-2: Average for 0.5 x 0.625 degree lat/lon region = 0.0 meters
# The value for missing source data that cannot be computed or is outside of the sources availability range: -999
# parameter(s):
# T2M             MERRA-2 Temperature at 2 Meters (C)
# WS2M            MERRA-2 Wind Speed at 2 Meters (m/s)
# RH2M            MERRA-2 Relative Humidity at 2 Meters (%)
# PRECTOTCORR     MERRA-2 Precipitation Corrected (mm/day)
# -END HEADER-
# YEAR,DOY,T2M,WS2M,RH2M,PRECTOTCORR
# 2015,1,21.68,5.52,91.69,0.63
# 2015,2,21.72,3.83,97.55,1.51
# 요청 중: 클러스터 5 (위도 -33.764374999999944, 경도 154.86062499999971)
# 응답 데이터 상단 15줄 (위도: -33.764374999999944, 경도: 154.86062499999971):
# -BEGIN HEADER-
# NASA/POWER Source Native Resolution Daily Data
# Dates (month/day/year): 01/01/2015 through 02/28/2025 in LST
# Location: latitude  -33.7644   longitude 154.8606
# elevation from MERRA-2: Average for 0.5 x 0.625 degree lat/lon region = 0.0 meters
# The value for missing source data that cannot be computed or is outside of the sources availability range: -999
# parameter(s):
# T2M             MERRA-2 Temperature at 2 Meters (C)
# WS2M            MERRA-2 Wind Speed at 2 Meters (m/s)
# RH2M            MERRA-2 Relative Humidity at 2 Meters (%)
# PRECTOTCORR     MERRA-2 Precipitation Corrected (mm/day)
# -END HEADER-
# YEAR,DOY,T2M,WS2M,RH2M,PRECTOTCORR
# 2015,1,23.55,6.18,78.79,1.44
# 2015,2,24.5,6.08,83.56,8.35
# 요청 중: 클러스터 6 (위도 -30.935031847133665, 경도 151.5675159235668)
# 응답 데이터 상단 15줄 (위도: -30.935031847133665, 경도: 151.5675159235668):
# -BEGIN HEADER-
# NASA/POWER Source Native Resolution Daily Data
# Dates (month/day/year): 01/01/2015 through 02/28/2025 in LST
# Location: latitude  -30.935   longitude 151.5675
# elevation from MERRA-2: Average for 0.5 x 0.625 degree lat/lon region = 945.13 meters
# The value for missing source data that cannot be computed or is outside of the sources availability range: -999
# parameter(s):
# T2M             MERRA-2 Temperature at 2 Meters (C)
# WS2M            MERRA-2 Wind Speed at 2 Meters (m/s)
# RH2M            MERRA-2 Relative Humidity at 2 Meters (%)
# PRECTOTCORR     MERRA-2 Precipitation Corrected (mm/day)
# -END HEADER-
# YEAR,DOY,T2M,WS2M,RH2M,PRECTOTCORR
# 2015,1,21.3,1.16,74.14,0.62
# 2015,2,18.62,0.73,90.53,8.93
# 요청 중: 클러스터 7 (위도 -30.826060606060512, 경도 158.26242424242378)
# 응답 데이터 상단 15줄 (위도: -30.826060606060512, 경도: 158.26242424242378):
# -BEGIN HEADER-
# NASA/POWER Source Native Resolution Daily Data
# Dates (month/day/year): 01/01/2015 through 02/28/2025 in LST
# Location: latitude  -30.8261   longitude 158.2624
# elevation from MERRA-2: Average for 0.5 x 0.625 degree lat/lon region = 0.0 meters
# The value for missing source data that cannot be computed or is outside of the sources availability range: -999
# parameter(s):
# T2M             MERRA-2 Temperature at 2 Meters (C)
# WS2M            MERRA-2 Wind Speed at 2 Meters (m/s)
# RH2M            MERRA-2 Relative Humidity at 2 Meters (%)
# PRECTOTCORR     MERRA-2 Precipitation Corrected (mm/day)
# -END HEADER-
# YEAR,DOY,T2M,WS2M,RH2M,PRECTOTCORR
# 2015,1,23.33,5.37,78.85,0.17
# 2015,2,23.42,4.85,79.28,1.85
# 요청 중: 클러스터 8 (위도 -37.0578947368421, 경도 158.28421052631532)
# 응답 데이터 상단 15줄 (위도: -37.0578947368421, 경도: 158.28421052631532):
# -BEGIN HEADER-
# NASA/POWER Source Native Resolution Daily Data
# Dates (month/day/year): 01/01/2015 through 02/28/2025 in LST
# Location: latitude  -37.0579   longitude 158.2842
# elevation from MERRA-2: Average for 0.5 x 0.625 degree lat/lon region = 0.0 meters
# The value for missing source data that cannot be computed or is outside of the sources availability range: -999
# parameter(s):
# T2M             MERRA-2 Temperature at 2 Meters (C)
# WS2M            MERRA-2 Wind Speed at 2 Meters (m/s)
# RH2M            MERRA-2 Relative Humidity at 2 Meters (%)
# PRECTOTCORR     MERRA-2 Precipitation Corrected (mm/day)
# -END HEADER-
# YEAR,DOY,T2M,WS2M,RH2M,PRECTOTCORR
# 2015,1,20.18,4.8,71.92,0.09
# 2015,2,20.84,4.76,80.24,0.0
# 요청 중: 클러스터 9 (위도 -35.57777777777775, 경도 157.14967320261397)
# 응답 데이터 상단 15줄 (위도: -35.57777777777775, 경도: 157.14967320261397):
# -BEGIN HEADER-
# NASA/POWER Source Native Resolution Daily Data
# Dates (month/day/year): 01/01/2015 through 02/28/2025 in LST
# Location: latitude  -35.5778   longitude 157.1497
# elevation from MERRA-2: Average for 0.5 x 0.625 degree lat/lon region = 0.0 meters
# The value for missing source data that cannot be computed or is outside of the sources availability range: -999
# parameter(s):
# T2M             MERRA-2 Temperature at 2 Meters (C)
# WS2M            MERRA-2 Wind Speed at 2 Meters (m/s)
# RH2M            MERRA-2 Relative Humidity at 2 Meters (%)
# PRECTOTCORR     MERRA-2 Precipitation Corrected (mm/day)
# -END HEADER-
# YEAR,DOY,T2M,WS2M,RH2M,PRECTOTCORR
# 2015,1,20.83,4.29,74.98,0.02
# 2015,2,21.63,5.01,83.9,1.01
# 요청 중: 클러스터 10 (위도 -32.16562499999993, 경도 158.36749999999952)
# 응답 데이터 상단 15줄 (위도: -32.16562499999993, 경도: 158.36749999999952):
# -BEGIN HEADER-
# NASA/POWER Source Native Resolution Daily Data
# Dates (month/day/year): 01/01/2015 through 02/28/2025 in LST
# Location: latitude  -32.1656   longitude 158.3675
# elevation from MERRA-2: Average for 0.5 x 0.625 degree lat/lon region = 0.0 meters
# The value for missing source data that cannot be computed or is outside of the sources availability range: -999
# parameter(s):
# T2M             MERRA-2 Temperature at 2 Meters (C)
# WS2M            MERRA-2 Wind Speed at 2 Meters (m/s)
# RH2M            MERRA-2 Relative Humidity at 2 Meters (%)
# PRECTOTCORR     MERRA-2 Precipitation Corrected (mm/day)
# -END HEADER-
# YEAR,DOY,T2M,WS2M,RH2M,PRECTOTCORR
# 2015,1,22.62,4.75,77.6,0.44
# 2015,2,23.08,4.51,78.79,2.04
# 요청 중: 클러스터 11 (위도 -29.550955414012623, 경도 152.04012738853493)
# 응답 데이터 상단 15줄 (위도: -29.550955414012623, 경도: 152.04012738853493):
# -BEGIN HEADER-
# NASA/POWER Source Native Resolution Daily Data
# Dates (month/day/year): 01/01/2015 through 02/28/2025 in LST
# Location: latitude  -29.551   longitude 152.0401
# elevation from MERRA-2: Average for 0.5 x 0.625 degree lat/lon region = 888.89 meters
# The value for missing source data that cannot be computed or is outside of the sources availability range: -999
# parameter(s):
# T2M             MERRA-2 Temperature at 2 Meters (C)
# WS2M            MERRA-2 Wind Speed at 2 Meters (m/s)
# RH2M            MERRA-2 Relative Humidity at 2 Meters (%)
# PRECTOTCORR     MERRA-2 Precipitation Corrected (mm/day)
# -END HEADER-
# YEAR,DOY,T2M,WS2M,RH2M,PRECTOTCORR
# 2015,1,22.55,1.52,73.23,1.07
# 2015,2,21.02,1.49,76.87,1.03
# 요청 중: 클러스터 12 (위도 -36.972027972027966, 경도 151.52797202797194)
# 응답 데이터 상단 15줄 (위도: -36.972027972027966, 경도: 151.52797202797194):
# -BEGIN HEADER-
# NASA/POWER Source Native Resolution Daily Data
# Dates (month/day/year): 01/01/2015 through 02/28/2025 in LST
# Location: latitude  -36.972   longitude 151.528
# elevation from MERRA-2: Average for 0.5 x 0.625 degree lat/lon region = 0.0 meters
# The value for missing source data that cannot be computed or is outside of the sources availability range: -999
# parameter(s):
# T2M             MERRA-2 Temperature at 2 Meters (C)
# WS2M            MERRA-2 Wind Speed at 2 Meters (m/s)
# RH2M            MERRA-2 Relative Humidity at 2 Meters (%)
# PRECTOTCORR     MERRA-2 Precipitation Corrected (mm/day)
# -END HEADER-
# YEAR,DOY,T2M,WS2M,RH2M,PRECTOTCORR
# 2015,1,20.12,4.93,91.17,0.16
# 2015,2,20.64,4.24,95.54,0.83
# 요청 중: 클러스터 13 (위도 -32.82170542635652, 경도 155.94496124030974)
# 응답 데이터 상단 15줄 (위도: -32.82170542635652, 경도: 155.94496124030974):
# -BEGIN HEADER-
# NASA/POWER Source Native Resolution Daily Data
# Dates (month/day/year): 01/01/2015 through 02/28/2025 in LST
# Location: latitude  -32.8217   longitude 155.945
# elevation from MERRA-2: Average for 0.5 x 0.625 degree lat/lon region = 0.0 meters
# The value for missing source data that cannot be computed or is outside of the sources availability range: -999
# parameter(s):
# T2M             MERRA-2 Temperature at 2 Meters (C)
# WS2M            MERRA-2 Wind Speed at 2 Meters (m/s)
# RH2M            MERRA-2 Relative Humidity at 2 Meters (%)
# PRECTOTCORR     MERRA-2 Precipitation Corrected (mm/day)
# -END HEADER-
# YEAR,DOY,T2M,WS2M,RH2M,PRECTOTCORR
# 2015,1,22.91,5.49,79.18,1.91
# 2015,2,23.43,5.91,85.31,10.7
# 요청 중: 클러스터 14 (위도 -36.05373134328356, 경도 154.76343283582062)
# 응답 데이터 상단 15줄 (위도: -36.05373134328356, 경도: 154.76343283582062):
# -BEGIN HEADER-
# NASA/POWER Source Native Resolution Daily Data
# Dates (month/day/year): 01/01/2015 through 02/28/2025 in LST
# Location: latitude  -36.0537   longitude 154.7634
# elevation from MERRA-2: Average for 0.5 x 0.625 degree lat/lon region = 0.0 meters
# The value for missing source data that cannot be computed or is outside of the sources availability range: -999
# parameter(s):
# T2M             MERRA-2 Temperature at 2 Meters (C)
# WS2M            MERRA-2 Wind Speed at 2 Meters (m/s)
# RH2M            MERRA-2 Relative Humidity at 2 Meters (%)
# PRECTOTCORR     MERRA-2 Precipitation Corrected (mm/day)
# -END HEADER-
# YEAR,DOY,T2M,WS2M,RH2M,PRECTOTCORR
# 2015,1,21.67,5.39,79.64,0.72
# 2015,2,22.48,5.94,89.71,11.13
# 요청 중: 클러스터 15 (위도 -31.67333333333325, 경도 155.88266666666632)
# 응답 데이터 상단 15줄 (위도: -31.67333333333325, 경도: 155.88266666666632):
# -BEGIN HEADER-
# NASA/POWER Source Native Resolution Daily Data
# Dates (month/day/year): 01/01/2015 through 02/28/2025 in LST
# Location: latitude  -31.6733   longitude 155.8827
# elevation from MERRA-2: Average for 0.5 x 0.625 degree lat/lon region = 0.0 meters
# The value for missing source data that cannot be computed or is outside of the sources availability range: -999
# parameter(s):
# T2M             MERRA-2 Temperature at 2 Meters (C)
# WS2M            MERRA-2 Wind Speed at 2 Meters (m/s)
# RH2M            MERRA-2 Relative Humidity at 2 Meters (%)
# PRECTOTCORR     MERRA-2 Precipitation Corrected (mm/day)
# -END HEADER-
# YEAR,DOY,T2M,WS2M,RH2M,PRECTOTCORR
# 2015,1,24.22,6.07,81.64,1.22
# 2015,2,24.55,5.53,83.18,5.43
# 요청 중: 클러스터 16 (위도 -34.81521739130431, 경도 150.39347826086956)
# 응답 데이터 상단 15줄 (위도: -34.81521739130431, 경도: 150.39347826086956):
# -BEGIN HEADER-
# NASA/POWER Source Native Resolution Daily Data
# Dates (month/day/year): 01/01/2015 through 02/28/2025 in LST
# Location: latitude  -34.8152   longitude 150.3935
# elevation from MERRA-2: Average for 0.5 x 0.625 degree lat/lon region = 118.91 meters
# The value for missing source data that cannot be computed or is outside of the sources availability range: -999
# parameter(s):
# T2M             MERRA-2 Temperature at 2 Meters (C)
# WS2M            MERRA-2 Wind Speed at 2 Meters (m/s)
# RH2M            MERRA-2 Relative Humidity at 2 Meters (%)
# PRECTOTCORR     MERRA-2 Precipitation Corrected (mm/day)
# -END HEADER-
# YEAR,DOY,T2M,WS2M,RH2M,PRECTOTCORR
# 2015,1,24.07,1.09,69.66,0.17
# 2015,2,23.55,1.16,77.45,0.63
# 요청 중: 클러스터 17 (위도 -34.7052631578947, 경도 152.41381578947355)
# 응답 데이터 상단 15줄 (위도: -34.7052631578947, 경도: 152.41381578947355):
# -BEGIN HEADER-
# NASA/POWER Source Native Resolution Daily Data
# Dates (month/day/year): 01/01/2015 through 02/28/2025 in LST
# Location: latitude  -34.7053   longitude 152.4138
# elevation from MERRA-2: Average for 0.5 x 0.625 degree lat/lon region = 0.0 meters
# The value for missing source data that cannot be computed or is outside of the sources availability range: -999
# parameter(s):
# T2M             MERRA-2 Temperature at 2 Meters (C)
# WS2M            MERRA-2 Wind Speed at 2 Meters (m/s)
# RH2M            MERRA-2 Relative Humidity at 2 Meters (%)
# PRECTOTCORR     MERRA-2 Precipitation Corrected (mm/day)
# -END HEADER-
# YEAR,DOY,T2M,WS2M,RH2M,PRECTOTCORR
# 2015,1,23.51,6.23,84.56,0.74
# 2015,2,23.57,3.86,94.26,4.66
# 요청 중: 클러스터 18 (위도 -29.72197802197791, 경도 150.63241758241756)
# 응답 데이터 상단 15줄 (위도: -29.72197802197791, 경도: 150.63241758241756):
# -BEGIN HEADER-
# NASA/POWER Source Native Resolution Daily Data
# Dates (month/day/year): 01/01/2015 through 02/28/2025 in LST
# Location: latitude  -29.722   longitude 150.6324
# elevation from MERRA-2: Average for 0.5 x 0.625 degree lat/lon region = 455.8 meters
# The value for missing source data that cannot be computed or is outside of the sources availability range: -999
# parameter(s):
# T2M             MERRA-2 Temperature at 2 Meters (C)
# WS2M            MERRA-2 Wind Speed at 2 Meters (m/s)
# RH2M            MERRA-2 Relative Humidity at 2 Meters (%)
# PRECTOTCORR     MERRA-2 Precipitation Corrected (mm/day)
# -END HEADER-
# YEAR,DOY,T2M,WS2M,RH2M,PRECTOTCORR
# 2015,1,27.53,3.36,55.97,1.34
# 2015,2,22.9,2.71,76.25,16.05
# 요청 중: 클러스터 19 (위도 -31.834328358208875, 경도 153.9507462686565)
# 응답 데이터 상단 15줄 (위도: -31.834328358208875, 경도: 153.9507462686565):
# -BEGIN HEADER-
# NASA/POWER Source Native Resolution Daily Data
# Dates (month/day/year): 01/01/2015 through 02/28/2025 in LST
# Location: latitude  -31.8343   longitude 153.9507
# elevation from MERRA-2: Average for 0.5 x 0.625 degree lat/lon region = 0.0 meters
# The value for missing source data that cannot be computed or is outside of the sources availability range: -999
# parameter(s):
# T2M             MERRA-2 Temperature at 2 Meters (C)
# WS2M            MERRA-2 Wind Speed at 2 Meters (m/s)
# RH2M            MERRA-2 Relative Humidity at 2 Meters (%)
# PRECTOTCORR     MERRA-2 Precipitation Corrected (mm/day)
# -END HEADER-
# YEAR,DOY,T2M,WS2M,RH2M,PRECTOTCORR
# 2015,1,24.6,6.61,84.22,0.98
# 2015,2,25.0,6.39,87.94,5.75
# 요청 중: 클러스터 20 (위도 -33.196610169491464, 경도 152.19378531073434)
# 응답 데이터 상단 15줄 (위도: -33.196610169491464, 경도: 152.19378531073434):
# -BEGIN HEADER-
# NASA/POWER Source Native Resolution Daily Data
# Dates (month/day/year): 01/01/2015 through 02/28/2025 in LST
# Location: latitude  -33.1966   longitude 152.1938
# elevation from MERRA-2: Average for 0.5 x 0.625 degree lat/lon region = 0.59 meters
# The value for missing source data that cannot be computed or is outside of the sources availability range: -999
# parameter(s):
# T2M             MERRA-2 Temperature at 2 Meters (C)
# WS2M            MERRA-2 Wind Speed at 2 Meters (m/s)
# RH2M            MERRA-2 Relative Humidity at 2 Meters (%)
# PRECTOTCORR     MERRA-2 Precipitation Corrected (mm/day)
# -END HEADER-
# YEAR,DOY,T2M,WS2M,RH2M,PRECTOTCORR
# 2015,1,24.13,6.58,84.31,1.25
# 2015,2,24.5,3.72,89.03,6.01
# 요청 중: 클러스터 21 (위도 -34.92534246575339, 경도 154.58356164383537)
# 응답 데이터 상단 15줄 (위도: -34.92534246575339, 경도: 154.58356164383537):
# -BEGIN HEADER-
# NASA/POWER Source Native Resolution Daily Data
# Dates (month/day/year): 01/01/2015 through 02/28/2025 in LST
# Location: latitude  -34.9253   longitude 154.5836
# elevation from MERRA-2: Average for 0.5 x 0.625 degree lat/lon region = 0.0 meters
# The value for missing source data that cannot be computed or is outside of the sources availability range: -999
# parameter(s):
# T2M             MERRA-2 Temperature at 2 Meters (C)
# WS2M            MERRA-2 Wind Speed at 2 Meters (m/s)
# RH2M            MERRA-2 Relative Humidity at 2 Meters (%)
# PRECTOTCORR     MERRA-2 Precipitation Corrected (mm/day)
# -END HEADER-
# YEAR,DOY,T2M,WS2M,RH2M,PRECTOTCORR
# 2015,1,23.04,5.99,79.81,1.11
# 2015,2,23.96,5.24,86.89,21.35
# 요청 중: 클러스터 22 (위도 -36.93515151515151, 경도 156.95757575757537)
# 응답 데이터 상단 15줄 (위도: -36.93515151515151, 경도: 156.95757575757537):
# -BEGIN HEADER-
# NASA/POWER Source Native Resolution Daily Data
# Dates (month/day/year): 01/01/2015 through 02/28/2025 in LST
# Location: latitude  -36.9352   longitude 156.9576
# elevation from MERRA-2: Average for 0.5 x 0.625 degree lat/lon region = 0.0 meters
# The value for missing source data that cannot be computed or is outside of the sources availability range: -999
# parameter(s):
# T2M             MERRA-2 Temperature at 2 Meters (C)
# WS2M            MERRA-2 Wind Speed at 2 Meters (m/s)
# RH2M            MERRA-2 Relative Humidity at 2 Meters (%)
# PRECTOTCORR     MERRA-2 Precipitation Corrected (mm/day)
# -END HEADER-
# YEAR,DOY,T2M,WS2M,RH2M,PRECTOTCORR
# 2015,1,20.36,5.3,75.48,0.01
# 2015,2,21.04,5.32,85.77,0.12
# 요청 중: 클러스터 23 (위도 -29.626256983240108, 경도 153.79608938547466)
# 응답 데이터 상단 15줄 (위도: -29.626256983240108, 경도: 153.79608938547466):
# -BEGIN HEADER-
# NASA/POWER Source Native Resolution Daily Data
# Dates (month/day/year): 01/01/2015 through 02/28/2025 in LST
# Location: latitude  -29.6263   longitude 153.7961
# elevation from MERRA-2: Average for 0.5 x 0.625 degree lat/lon region = 4.15 meters
# The value for missing source data that cannot be computed or is outside of the sources availability range: -999
# parameter(s):
# T2M             MERRA-2 Temperature at 2 Meters (C)
# WS2M            MERRA-2 Wind Speed at 2 Meters (m/s)
# RH2M            MERRA-2 Relative Humidity at 2 Meters (%)
# PRECTOTCORR     MERRA-2 Precipitation Corrected (mm/day)
# -END HEADER-
# YEAR,DOY,T2M,WS2M,RH2M,PRECTOTCORR
# 2015,1,25.59,5.39,85.79,4.85
# 2015,2,25.59,4.7,82.39,3.84
# 요청 중: 클러스터 24 (위도 -33.32810457516334, 경도 150.5117647058823)
# 응답 데이터 상단 15줄 (위도: -33.32810457516334, 경도: 150.5117647058823):
# -BEGIN HEADER-
# NASA/POWER Source Native Resolution Daily Data
# Dates (month/day/year): 01/01/2015 through 02/28/2025 in LST
# Location: latitude  -33.3281   longitude 150.5118
# elevation from MERRA-2: Average for 0.5 x 0.625 degree lat/lon region = 330.34 meters
# The value for missing source data that cannot be computed or is outside of the sources availability range: -999
# parameter(s):
# T2M             MERRA-2 Temperature at 2 Meters (C)
# WS2M            MERRA-2 Wind Speed at 2 Meters (m/s)
# RH2M            MERRA-2 Relative Humidity at 2 Meters (%)
# PRECTOTCORR     MERRA-2 Precipitation Corrected (mm/day)
# -END HEADER-
# YEAR,DOY,T2M,WS2M,RH2M,PRECTOTCORR
# 2015,1,25.71,0.25,60.79,0.37
# 2015,2,25.1,0.29,70.74,2.15
# 요청 중: 클러스터 25 (위도 -36.728301886792444, 경도 150.4264150943396)
# 응답 데이터 상단 15줄 (위도: -36.728301886792444, 경도: 150.4264150943396):
# -BEGIN HEADER-
# NASA/POWER Source Native Resolution Daily Data
# Dates (month/day/year): 01/01/2015 through 02/28/2025 in LST
# Location: latitude  -36.7283   longitude 150.4264
# elevation from MERRA-2: Average for 0.5 x 0.625 degree lat/lon region = 4.21 meters
# The value for missing source data that cannot be computed or is outside of the sources availability range: -999
# parameter(s):
# T2M             MERRA-2 Temperature at 2 Meters (C)
# WS2M            MERRA-2 Wind Speed at 2 Meters (m/s)
# RH2M            MERRA-2 Relative Humidity at 2 Meters (%)
# PRECTOTCORR     MERRA-2 Precipitation Corrected (mm/day)
# -END HEADER-
# YEAR,DOY,T2M,WS2M,RH2M,PRECTOTCORR
# 2015,1,20.24,4.45,91.33,0.19
# 2015,2,20.43,3.58,92.08,0.4
# 요청 중: 클러스터 26 (위도 -30.3969696969696, 경도 152.65378787878774)
# 응답 데이터 상단 15줄 (위도: -30.3969696969696, 경도: 152.65378787878774):
# -BEGIN HEADER-
# NASA/POWER Source Native Resolution Daily Data
# Dates (month/day/year): 01/01/2015 through 02/28/2025 in LST
# Location: latitude  -30.397   longitude 152.6538
# elevation from MERRA-2: Average for 0.5 x 0.625 degree lat/lon region = 558.38 meters
# The value for missing source data that cannot be computed or is outside of the sources availability range: -999
# parameter(s):
# T2M             MERRA-2 Temperature at 2 Meters (C)
# WS2M            MERRA-2 Wind Speed at 2 Meters (m/s)
# RH2M            MERRA-2 Relative Humidity at 2 Meters (%)
# PRECTOTCORR     MERRA-2 Precipitation Corrected (mm/day)
# -END HEADER-
# YEAR,DOY,T2M,WS2M,RH2M,PRECTOTCORR
# 2015,1,22.8,0.12,80.56,2.16
# 2015,2,21.68,0.1,85.71,1.82
# 요청 중: 클러스터 27 (위도 -35.68322981366457, 경도 153.4832298136644)
# 응답 데이터 상단 15줄 (위도: -35.68322981366457, 경도: 153.4832298136644):
# -BEGIN HEADER-
# NASA/POWER Source Native Resolution Daily Data
# Dates (month/day/year): 01/01/2015 through 02/28/2025 in LST
# Location: latitude  -35.6832   longitude 153.4832
# elevation from MERRA-2: Average for 0.5 x 0.625 degree lat/lon region = 0.0 meters
# The value for missing source data that cannot be computed or is outside of the sources availability range: -999
# parameter(s):
# T2M             MERRA-2 Temperature at 2 Meters (C)
# WS2M            MERRA-2 Wind Speed at 2 Meters (m/s)
# RH2M            MERRA-2 Relative Humidity at 2 Meters (%)
# PRECTOTCORR     MERRA-2 Precipitation Corrected (mm/day)
# -END HEADER-
# YEAR,DOY,T2M,WS2M,RH2M,PRECTOTCORR
# 2015,1,22.43,5.45,83.76,1.12
# 2015,2,23.11,4.32,91.73,7.78
# 요청 중: 클러스터 28 (위도 -31.45426829268284, 경도 157.1920731707313)
# 응답 데이터 상단 15줄 (위도: -31.45426829268284, 경도: 157.1920731707313):
# -BEGIN HEADER-
# NASA/POWER Source Native Resolution Daily Data
# Dates (month/day/year): 01/01/2015 through 02/28/2025 in LST
# Location: latitude  -31.4543   longitude 157.1921
# elevation from MERRA-2: Average for 0.5 x 0.625 degree lat/lon region = 0.0 meters
# The value for missing source data that cannot be computed or is outside of the sources availability range: -999
# parameter(s):
# T2M             MERRA-2 Temperature at 2 Meters (C)
# WS2M            MERRA-2 Wind Speed at 2 Meters (m/s)
# RH2M            MERRA-2 Relative Humidity at 2 Meters (%)
# PRECTOTCORR     MERRA-2 Precipitation Corrected (mm/day)
# -END HEADER-
# YEAR,DOY,T2M,WS2M,RH2M,PRECTOTCORR
# 2015,1,23.07,5.36,80.51,0.48
# 2015,2,23.41,4.92,80.56,2.92
# 요청 중: 클러스터 29 (위도 -34.793835616438315, 경도 158.37397260273926)
# 응답 데이터 상단 15줄 (위도: -34.793835616438315, 경도: 158.37397260273926):
# -BEGIN HEADER-
# NASA/POWER Source Native Resolution Daily Data
# Dates (month/day/year): 01/01/2015 through 02/28/2025 in LST
# Location: latitude  -34.7938   longitude 158.374
# elevation from MERRA-2: Average for 0.5 x 0.625 degree lat/lon region = 0.0 meters
# The value for missing source data that cannot be computed or is outside of the sources availability range: -999
# parameter(s):
# T2M             MERRA-2 Temperature at 2 Meters (C)
# WS2M            MERRA-2 Wind Speed at 2 Meters (m/s)
# RH2M            MERRA-2 Relative Humidity at 2 Meters (%)
# PRECTOTCORR     MERRA-2 Precipitation Corrected (mm/day)
# -END HEADER-
# YEAR,DOY,T2M,WS2M,RH2M,PRECTOTCORR
# 2015,1,20.73,3.41,68.99,0.03
# 2015,2,21.2,4.43,79.01,0.05
# 요청 중: 클러스터 30 (위도 -34.92847222222218, 경도 155.8722222222219)
# 응답 데이터 상단 15줄 (위도: -34.92847222222218, 경도: 155.8722222222219):
# -BEGIN HEADER-
# NASA/POWER Source Native Resolution Daily Data
# Dates (month/day/year): 01/01/2015 through 02/28/2025 in LST
# Location: latitude  -34.9285   longitude 155.8722
# elevation from MERRA-2: Average for 0.5 x 0.625 degree lat/lon region = 0.0 meters
# The value for missing source data that cannot be computed or is outside of the sources availability range: -999
# parameter(s):
# T2M             MERRA-2 Temperature at 2 Meters (C)
# WS2M            MERRA-2 Wind Speed at 2 Meters (m/s)
# RH2M            MERRA-2 Relative Humidity at 2 Meters (%)
# PRECTOTCORR     MERRA-2 Precipitation Corrected (mm/day)
# -END HEADER-
# YEAR,DOY,T2M,WS2M,RH2M,PRECTOTCORR
# 2015,1,22.27,5.71,77.1,0.65
# 2015,2,23.01,6.25,86.1,18.22
# 요청 중: 클러스터 31 (위도 -36.045864661654115, 경도 156.0037593984959)
# 응답 데이터 상단 15줄 (위도: -36.045864661654115, 경도: 156.0037593984959):
# -BEGIN HEADER-
# NASA/POWER Source Native Resolution Daily Data
# Dates (month/day/year): 01/01/2015 through 02/28/2025 in LST
# Location: latitude  -36.0459   longitude 156.0038
# elevation from MERRA-2: Average for 0.5 x 0.625 degree lat/lon region = 0.0 meters
# The value for missing source data that cannot be computed or is outside of the sources availability range: -999
# parameter(s):
# T2M             MERRA-2 Temperature at 2 Meters (C)
# WS2M            MERRA-2 Wind Speed at 2 Meters (m/s)
# RH2M            MERRA-2 Relative Humidity at 2 Meters (%)
# PRECTOTCORR     MERRA-2 Precipitation Corrected (mm/day)
# -END HEADER-
# YEAR,DOY,T2M,WS2M,RH2M,PRECTOTCORR
# 2015,1,20.65,4.83,78.02,0.04
# 2015,2,21.42,5.38,88.12,4.64
# 요청 중: 클러스터 32 (위도 -31.097183098591458, 경도 150.43591549295772)
# 응답 데이터 상단 15줄 (위도: -31.097183098591458, 경도: 150.43591549295772):
# -BEGIN HEADER-
# NASA/POWER Source Native Resolution Daily Data
# Dates (month/day/year): 01/01/2015 through 02/28/2025 in LST
# Location: latitude  -31.0972   longitude 150.4359
# elevation from MERRA-2: Average for 0.5 x 0.625 degree lat/lon region = 433.05 meters
# The value for missing source data that cannot be computed or is outside of the sources availability range: -999
# parameter(s):
# T2M             MERRA-2 Temperature at 2 Meters (C)
# WS2M            MERRA-2 Wind Speed at 2 Meters (m/s)
# RH2M            MERRA-2 Relative Humidity at 2 Meters (%)
# PRECTOTCORR     MERRA-2 Precipitation Corrected (mm/day)
# -END HEADER-
# YEAR,DOY,T2M,WS2M,RH2M,PRECTOTCORR
# 2015,1,27.86,2.76,51.81,0.12
# 2015,2,22.65,2.25,82.32,20.62
# 요청 중: 클러스터 33 (위도 -32.476027397260204, 경도 154.84109589041068)
# 응답 데이터 상단 15줄 (위도: -32.476027397260204, 경도: 154.84109589041068):
# -BEGIN HEADER-
# NASA/POWER Source Native Resolution Daily Data
# Dates (month/day/year): 01/01/2015 through 02/28/2025 in LST
# Location: latitude  -32.476   longitude 154.8411
# elevation from MERRA-2: Average for 0.5 x 0.625 degree lat/lon region = 0.0 meters
# The value for missing source data that cannot be computed or is outside of the sources availability range: -999
# parameter(s):
# T2M             MERRA-2 Temperature at 2 Meters (C)
# WS2M            MERRA-2 Wind Speed at 2 Meters (m/s)
# RH2M            MERRA-2 Relative Humidity at 2 Meters (%)
# PRECTOTCORR     MERRA-2 Precipitation Corrected (mm/day)
# -END HEADER-
# YEAR,DOY,T2M,WS2M,RH2M,PRECTOTCORR
# 2015,1,23.93,6.2,81.82,1.06
# 2015,2,24.64,5.87,84.06,6.49
# 요청 중: 클러스터 34 (위도 -36.97891156462585, 경도 152.82244897959168)
# 응답 데이터 상단 15줄 (위도: -36.97891156462585, 경도: 152.82244897959168):
# -BEGIN HEADER-
# NASA/POWER Source Native Resolution Daily Data
# Dates (month/day/year): 01/01/2015 through 02/28/2025 in LST
# Location: latitude  -36.9789   longitude 152.8224
# elevation from MERRA-2: Average for 0.5 x 0.625 degree lat/lon region = 0.0 meters
# The value for missing source data that cannot be computed or is outside of the sources availability range: -999
# parameter(s):
# T2M             MERRA-2 Temperature at 2 Meters (C)
# WS2M            MERRA-2 Wind Speed at 2 Meters (m/s)
# RH2M            MERRA-2 Relative Humidity at 2 Meters (%)
# PRECTOTCORR     MERRA-2 Precipitation Corrected (mm/day)
# -END HEADER-
# YEAR,DOY,T2M,WS2M,RH2M,PRECTOTCORR
# 2015,1,20.54,4.61,88.29,1.06
# 2015,2,21.45,3.67,96.69,4.49
# 요청 중: 클러스터 35 (위도 -32.96242038216554, 경도 153.5452229299361)
# 응답 데이터 상단 15줄 (위도: -32.96242038216554, 경도: 153.5452229299361):
# -BEGIN HEADER-
# NASA/POWER Source Native Resolution Daily Data
# Dates (month/day/year): 01/01/2015 through 02/28/2025 in LST
# Location: latitude  -32.9624   longitude 153.5452
# elevation from MERRA-2: Average for 0.5 x 0.625 degree lat/lon region = 0.0 meters
# The value for missing source data that cannot be computed or is outside of the sources availability range: -999
# parameter(s):
# T2M             MERRA-2 Temperature at 2 Meters (C)
# WS2M            MERRA-2 Wind Speed at 2 Meters (m/s)
# RH2M            MERRA-2 Relative Humidity at 2 Meters (%)
# PRECTOTCORR     MERRA-2 Precipitation Corrected (mm/day)
# -END HEADER-
# YEAR,DOY,T2M,WS2M,RH2M,PRECTOTCORR
# 2015,1,24.13,6.61,82.81,0.77
# 2015,2,24.78,6.11,87.36,7.09
# 요청 중: 클러스터 36 (위도 -34.1359154929577, 경도 151.39436619718302)
# 응답 데이터 상단 15줄 (위도: -34.1359154929577, 경도: 151.39436619718302):
# -BEGIN HEADER-
# NASA/POWER Source Native Resolution Daily Data
# Dates (month/day/year): 01/01/2015 through 02/28/2025 in LST
# Location: latitude  -34.1359   longitude 151.3944
# elevation from MERRA-2: Average for 0.5 x 0.625 degree lat/lon region = 31.72 meters
# The value for missing source data that cannot be computed or is outside of the sources availability range: -999
# parameter(s):
# T2M             MERRA-2 Temperature at 2 Meters (C)
# WS2M            MERRA-2 Wind Speed at 2 Meters (m/s)
# RH2M            MERRA-2 Relative Humidity at 2 Meters (%)
# PRECTOTCORR     MERRA-2 Precipitation Corrected (mm/day)
# -END HEADER-
# YEAR,DOY,T2M,WS2M,RH2M,PRECTOTCORR
# 2015,1,23.47,2.56,80.67,0.17
# 2015,2,23.61,1.43,87.33,1.21
# 요청 중: 클러스터 37 (위도 -29.670224719101007, 경도 156.97584269662883)
# 응답 데이터 상단 15줄 (위도: -29.670224719101007, 경도: 156.97584269662883):
# -BEGIN HEADER-
# NASA/POWER Source Native Resolution Daily Data
# Dates (month/day/year): 01/01/2015 through 02/28/2025 in LST
# Location: latitude  -29.6702   longitude 156.9758
# elevation from MERRA-2: Average for 0.5 x 0.625 degree lat/lon region = 0.0 meters
# The value for missing source data that cannot be computed or is outside of the sources availability range: -999
# parameter(s):
# T2M             MERRA-2 Temperature at 2 Meters (C)
# WS2M            MERRA-2 Wind Speed at 2 Meters (m/s)
# RH2M            MERRA-2 Relative Humidity at 2 Meters (%)
# PRECTOTCORR     MERRA-2 Precipitation Corrected (mm/day)
# -END HEADER-
# YEAR,DOY,T2M,WS2M,RH2M,PRECTOTCORR
# 2015,1,24.5,5.64,85.62,2.4
# 2015,2,24.08,5.22,85.25,1.35
# 요청 중: 클러스터 38 (위도 -32.82024539877294, 경도 157.17730061349653)
# 응답 데이터 상단 15줄 (위도: -32.82024539877294, 경도: 157.17730061349653):
# -BEGIN HEADER-
# NASA/POWER Source Native Resolution Daily Data
# Dates (month/day/year): 01/01/2015 through 02/28/2025 in LST
# Location: latitude  -32.8202   longitude 157.1773
# elevation from MERRA-2: Average for 0.5 x 0.625 degree lat/lon region = 0.0 meters
# The value for missing source data that cannot be computed or is outside of the sources availability range: -999
# parameter(s):
# T2M             MERRA-2 Temperature at 2 Meters (C)
# WS2M            MERRA-2 Wind Speed at 2 Meters (m/s)
# RH2M            MERRA-2 Relative Humidity at 2 Meters (%)
# PRECTOTCORR     MERRA-2 Precipitation Corrected (mm/day)
# -END HEADER-
# YEAR,DOY,T2M,WS2M,RH2M,PRECTOTCORR
# 2015,1,22.62,5.09,77.77,1.3
# 2015,2,23.02,5.55,83.32,6.56
# 요청 중: 클러스터 39 (위도 -34.18606060606056, 경도 153.4939393939392)
# 응답 데이터 상단 15줄 (위도: -34.18606060606056, 경도: 153.4939393939392):
# -BEGIN HEADER-
# NASA/POWER Source Native Resolution Daily Data
# Dates (month/day/year): 01/01/2015 through 02/28/2025 in LST
# Location: latitude  -34.1861   longitude 153.4939
# elevation from MERRA-2: Average for 0.5 x 0.625 degree lat/lon region = 0.0 meters
# The value for missing source data that cannot be computed or is outside of the sources availability range: -999
# parameter(s):
# T2M             MERRA-2 Temperature at 2 Meters (C)
# WS2M            MERRA-2 Wind Speed at 2 Meters (m/s)
# RH2M            MERRA-2 Relative Humidity at 2 Meters (%)
# PRECTOTCORR     MERRA-2 Precipitation Corrected (mm/day)
# -END HEADER-
# YEAR,DOY,T2M,WS2M,RH2M,PRECTOTCORR
# 2015,1,23.88,6.69,81.44,0.88
# 2015,2,24.6,5.56,85.74,6.31
# 요청 중: 클러스터 40 (위도 -30.541059602648907, 경도 156.2490066225162)
# 응답 데이터 상단 15줄 (위도: -30.541059602648907, 경도: 156.2490066225162):
# -BEGIN HEADER-
# NASA/POWER Source Native Resolution Daily Data
# Dates (month/day/year): 01/01/2015 through 02/28/2025 in LST
# Location: latitude  -30.5411   longitude 156.249
# elevation from MERRA-2: Average for 0.5 x 0.625 degree lat/lon region = 0.0 meters
# The value for missing source data that cannot be computed or is outside of the sources availability range: -999
# parameter(s):
# T2M             MERRA-2 Temperature at 2 Meters (C)
# WS2M            MERRA-2 Wind Speed at 2 Meters (m/s)
# RH2M            MERRA-2 Relative Humidity at 2 Meters (%)
# PRECTOTCORR     MERRA-2 Precipitation Corrected (mm/day)
# -END HEADER-
# YEAR,DOY,T2M,WS2M,RH2M,PRECTOTCORR
# 2015,1,24.37,5.82,82.92,1.03
# 2015,2,24.22,5.2,84.25,2.53
# 요청 중: 클러스터 41 (위도 -35.99863013698628, 경도 158.29863013698582)
# 응답 데이터 상단 15줄 (위도: -35.99863013698628, 경도: 158.29863013698582):
# -BEGIN HEADER-
# NASA/POWER Source Native Resolution Daily Data
# Dates (month/day/year): 01/01/2015 through 02/28/2025 in LST
# Location: latitude  -35.9986   longitude 158.2986
# elevation from MERRA-2: Average for 0.5 x 0.625 degree lat/lon region = 0.0 meters
# The value for missing source data that cannot be computed or is outside of the sources availability range: -999
# parameter(s):
# T2M             MERRA-2 Temperature at 2 Meters (C)
# WS2M            MERRA-2 Wind Speed at 2 Meters (m/s)
# RH2M            MERRA-2 Relative Humidity at 2 Meters (%)
# PRECTOTCORR     MERRA-2 Precipitation Corrected (mm/day)
# -END HEADER-
# YEAR,DOY,T2M,WS2M,RH2M,PRECTOTCORR
# 2015,1,20.27,3.92,70.47,0.02
# 2015,2,20.83,4.64,80.25,0.0
# 요청 중: 클러스터 42 (위도 -35.91666666666664, 경도 152.2586956521738)
# 응답 데이터 상단 15줄 (위도: -35.91666666666664, 경도: 152.2586956521738):
# -BEGIN HEADER-
# NASA/POWER Source Native Resolution Daily Data
# Dates (month/day/year): 01/01/2015 through 02/28/2025 in LST
# Location: latitude  -35.9167   longitude 152.2587
# elevation from MERRA-2: Average for 0.5 x 0.625 degree lat/lon region = 0.0 meters
# The value for missing source data that cannot be computed or is outside of the sources availability range: -999
# parameter(s):
# T2M             MERRA-2 Temperature at 2 Meters (C)
# WS2M            MERRA-2 Wind Speed at 2 Meters (m/s)
# RH2M            MERRA-2 Relative Humidity at 2 Meters (%)
# PRECTOTCORR     MERRA-2 Precipitation Corrected (mm/day)
# -END HEADER-
# YEAR,DOY,T2M,WS2M,RH2M,PRECTOTCORR
# 2015,1,21.36,4.77,89.63,0.92
# 2015,2,21.88,3.66,97.19,5.09
# 요청 중: 클러스터 43 (위도 -30.812426035502867, 경도 154.82721893491097)
# 응답 데이터 상단 15줄 (위도: -30.812426035502867, 경도: 154.82721893491097):
# -BEGIN HEADER-
# NASA/POWER Source Native Resolution Daily Data
# Dates (month/day/year): 01/01/2015 through 02/28/2025 in LST
# Location: latitude  -30.8124   longitude 154.8272
# elevation from MERRA-2: Average for 0.5 x 0.625 degree lat/lon region = 0.0 meters
# The value for missing source data that cannot be computed or is outside of the sources availability range: -999
# parameter(s):
# T2M             MERRA-2 Temperature at 2 Meters (C)
# WS2M            MERRA-2 Wind Speed at 2 Meters (m/s)
# RH2M            MERRA-2 Relative Humidity at 2 Meters (%)
# PRECTOTCORR     MERRA-2 Precipitation Corrected (mm/day)
# -END HEADER-
# YEAR,DOY,T2M,WS2M,RH2M,PRECTOTCORR
# 2015,1,24.46,6.15,84.82,0.78
# 2015,2,24.58,5.59,86.3,3.39
# 요청 중: 클러스터 44 (위도 -31.921348314606664, 경도 152.47415730337065)
# 응답 데이터 상단 15줄 (위도: -31.921348314606664, 경도: 152.47415730337065):
# -BEGIN HEADER-
# NASA/POWER Source Native Resolution Daily Data
# Dates (month/day/year): 01/01/2015 through 02/28/2025 in LST
# Location: latitude  -31.9213   longitude 152.4742
# elevation from MERRA-2: Average for 0.5 x 0.625 degree lat/lon region = 83.6 meters
# The value for missing source data that cannot be computed or is outside of the sources availability range: -999
# parameter(s):
# T2M             MERRA-2 Temperature at 2 Meters (C)
# WS2M            MERRA-2 Wind Speed at 2 Meters (m/s)
# RH2M            MERRA-2 Relative Humidity at 2 Meters (%)
# PRECTOTCORR     MERRA-2 Precipitation Corrected (mm/day)
# -END HEADER-
# YEAR,DOY,T2M,WS2M,RH2M,PRECTOTCORR
# 2015,1,25.25,2.53,75.82,0.83
# 2015,2,24.56,1.42,82.39,2.32
# 요청 중: 클러스터 45 (위도 -32.249456521739056, 경도 150.90923913043474)
# 응답 데이터 상단 15줄 (위도: -32.249456521739056, 경도: 150.90923913043474):
# -BEGIN HEADER-
# NASA/POWER Source Native Resolution Daily Data
# Dates (month/day/year): 01/01/2015 through 02/28/2025 in LST
# Location: latitude  -32.2495   longitude 150.9092
# elevation from MERRA-2: Average for 0.5 x 0.625 degree lat/lon region = 386.88 meters
# The value for missing source data that cannot be computed or is outside of the sources availability range: -999
# parameter(s):
# T2M             MERRA-2 Temperature at 2 Meters (C)
# WS2M            MERRA-2 Wind Speed at 2 Meters (m/s)
# RH2M            MERRA-2 Relative Humidity at 2 Meters (%)
# PRECTOTCORR     MERRA-2 Precipitation Corrected (mm/day)
# -END HEADER-
# YEAR,DOY,T2M,WS2M,RH2M,PRECTOTCORR
# 2015,1,27.52,1.6,53.56,0.17
# 2015,2,23.79,1.36,76.01,8.17
# 요청 중: 클러스터 46 (위도 -29.649999999999885, 경도 158.29999999999953)
# 응답 데이터 상단 15줄 (위도: -29.649999999999885, 경도: 158.29999999999953):
# -BEGIN HEADER-
# NASA/POWER Source Native Resolution Daily Data
# Dates (month/day/year): 01/01/2015 through 02/28/2025 in LST
# Location: latitude  -29.65   longitude 158.3
# elevation from MERRA-2: Average for 0.5 x 0.625 degree lat/lon region = 0.0 meters
# The value for missing source data that cannot be computed or is outside of the sources availability range: -999
# parameter(s):
# T2M             MERRA-2 Temperature at 2 Meters (C)
# WS2M            MERRA-2 Wind Speed at 2 Meters (m/s)
# RH2M            MERRA-2 Relative Humidity at 2 Meters (%)
# PRECTOTCORR     MERRA-2 Precipitation Corrected (mm/day)
# -END HEADER-
# YEAR,DOY,T2M,WS2M,RH2M,PRECTOTCORR
# 2015,1,24.48,5.93,81.73,1.3
# 2015,2,24.05,5.35,80.65,0.87
# 요청 중: 클러스터 47 (위도 -33.5006369426751, 경도 158.3394904458594)
# 응답 데이터 상단 15줄 (위도: -33.5006369426751, 경도: 158.3394904458594):
# -BEGIN HEADER-
# NASA/POWER Source Native Resolution Daily Data
# Dates (month/day/year): 01/01/2015 through 02/28/2025 in LST
# Location: latitude  -33.5006   longitude 158.3395
# elevation from MERRA-2: Average for 0.5 x 0.625 degree lat/lon region = 0.0 meters
# The value for missing source data that cannot be computed or is outside of the sources availability range: -999
# parameter(s):
# T2M             MERRA-2 Temperature at 2 Meters (C)
# WS2M            MERRA-2 Wind Speed at 2 Meters (m/s)
# RH2M            MERRA-2 Relative Humidity at 2 Meters (%)
# PRECTOTCORR     MERRA-2 Precipitation Corrected (mm/day)
# -END HEADER-
# YEAR,DOY,T2M,WS2M,RH2M,PRECTOTCORR
# 2015,1,21.94,4.04,72.6,0.29
# 2015,2,22.35,4.41,78.1,0.6
# 요청 중: 클러스터 48 (위도 -37.063636363636355, 경도 155.4999999999997)
# 응답 데이터 상단 15줄 (위도: -37.063636363636355, 경도: 155.4999999999997):
# -BEGIN HEADER-
# NASA/POWER Source Native Resolution Daily Data
# Dates (month/day/year): 01/01/2015 through 02/28/2025 in LST
# Location: latitude  -37.0636   longitude 155.5
# elevation from MERRA-2: Average for 0.5 x 0.625 degree lat/lon region = 0.0 meters
# The value for missing source data that cannot be computed or is outside of the sources availability range: -999
# parameter(s):
# T2M             MERRA-2 Temperature at 2 Meters (C)
# WS2M            MERRA-2 Wind Speed at 2 Meters (m/s)
# RH2M            MERRA-2 Relative Humidity at 2 Meters (%)
# PRECTOTCORR     MERRA-2 Precipitation Corrected (mm/day)
# -END HEADER-
# YEAR,DOY,T2M,WS2M,RH2M,PRECTOTCORR
# 2015,1,20.52,5.59,79.76,0.24
# 2015,2,21.31,5.89,90.57,6.4
# 요청 중: 클러스터 49 (위도 -33.85348837209297, 경도 156.2054263565888)
# 응답 데이터 상단 15줄 (위도: -33.85348837209297, 경도: 156.2054263565888):
# -BEGIN HEADER-
# NASA/POWER Source Native Resolution Daily Data
# Dates (month/day/year): 01/01/2015 through 02/28/2025 in LST
# Location: latitude  -33.8535   longitude 156.2054
# elevation from MERRA-2: Average for 0.5 x 0.625 degree lat/lon region = 0.0 meters
# The value for missing source data that cannot be computed or is outside of the sources availability range: -999
# parameter(s):
# T2M             MERRA-2 Temperature at 2 Meters (C)
# WS2M            MERRA-2 Wind Speed at 2 Meters (m/s)
# RH2M            MERRA-2 Relative Humidity at 2 Meters (%)
# PRECTOTCORR     MERRA-2 Precipitation Corrected (mm/day)
# -END HEADER-
# YEAR,DOY,T2M,WS2M,RH2M,PRECTOTCORR
# 2015,1,22.41,5.15,76.43,0.84
# 2015,2,23.11,5.96,84.99,8.53
#
# 기상 데이터 정보:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 185600 entries, 0 to 185599
# Data columns (total 9 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   YEAR         185600 non-null  int64
#  1   DOY          185600 non-null  int64
#  2   T2M          185600 non-null  float64
#  3   WS2M         185600 non-null  float64
#  4   RH2M         185600 non-null  float64
#  5   PRECTOTCORR  185600 non-null  float64
#  6   latitude     185600 non-null  float64
#  7   longitude    185600 non-null  float64
#  8   acq_date     185600 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), float64(6), int64(2)
# memory usage: 12.7 MB
# None
#    YEAR  DOY    T2M  WS2M   RH2M  PRECTOTCORR   latitude   longitude  \
# 0  2015    1  21.95  4.15  71.47         0.03 -34.292105  157.235526
# 1  2015    2  22.51  4.82  78.88         0.55 -34.292105  157.235526
# 2  2015    3  22.32  5.28  75.58         0.07 -34.292105  157.235526
# 3  2015    4  22.37  5.22  76.27         0.63 -34.292105  157.235526
# 4  2015    5  22.72  3.13  83.35         2.77 -34.292105  157.235526
#
#     acq_date
# 0 2015-01-01
# 1 2015-01-02
# 2 2015-01-03
# 3 2015-01-04
# 4 2015-01-05

# %% [markdown]
# #### 산불 데이터와 기상데이터를 더해서 하나의 CSV 파일로 생성

# %%
# Haversine 공식으로 거리 계산
def haversine(lat1, lon1, lat2, lon2):
    R = 6371  # 지구 반지름 (km)
    lat1, lon1, lat2, lon2 = map(radians, [lat1, lon1, lat2, lon2])
    dlat = lat2 - lat1
    dlon = lon2 - lon1
    a = sin(dlat/2)**2 + cos(lat1) * cos(lat2) * sin(dlon/2)**2
    c = 2 * atan2(sqrt(a), sqrt(1-a))
    return R * c

# IDW(역거리 가중 보간) 함수
def idw_interpolation(row, weather_df, weather_vars):
    # 동일 날짜의 기상 데이터만 필터링
    weather_subset = weather_df[weather_df["acq_date"] == row["acq_date"]]
    if weather_subset.empty:
        return pd.Series([None] * len(weather_vars), index=weather_vars)
    
    distances = weather_subset.apply(
        lambda w: haversine(row["latitude"], row["longitude"], w["latitude"], w["longitude"]), axis=1
    )
    # 거리가 0인 경우를 방지하기 위해 최소값 설정
    distances = distances.replace(0, 1e-10)
    weights = 1 / (distances ** 2)
    weighted_sum = (weather_subset[weather_vars].multiply(weights, axis=0)).sum()
    return weighted_sum / weights.sum()

# 1. 산불 데이터 로드
wildfire_dfs = {
    'aS1': pd.read_csv("./data/csv/fire_archive_SV-C2_591013.csv"),
    'nS1': pd.read_csv("./data/csv/fire_nrt_SV-C2_591013.csv"),
}

# 2. 날씨 데이터 로드
weather_df = pd.read_csv("./data/csv/weather_data.csv")

# 3. 성능 최적화: dtypes 최적화
# 메모리 사용량을 줄이기 위해 float32 사용
for df in wildfire_dfs.values():
    df["latitude"] = df["latitude"].astype("float32")
    df["longitude"] = df["longitude"].astype("float32")

weather_df["latitude"] = weather_df["latitude"].astype("float32")
weather_df["longitude"] = weather_df["longitude"].astype("float32")
weather_df["T2M"] = weather_df["T2M"].astype("float32")
weather_df["WS2M"] = weather_df["WS2M"].astype("float32")
weather_df["RH2M"] = weather_df["RH2M"].astype("float32")
weather_df["PRECTOTCORR"] = weather_df["PRECTOTCORR"].astype("float32")

# 4. 산불 데이터 처리
for df in wildfire_dfs.values():
    df["acq_date"] = pd.to_datetime(df["acq_date"])

wildfire_df = pd.concat(wildfire_dfs.values(), ignore_index=True)

# 5. 기상 데이터 처리
weather_df["acq_date"] = pd.to_datetime(weather_df["YEAR"].astype(str) + weather_df["DOY"].astype(str), format="%Y%j")

# 성능 최적화: 병합 전 필터링 (2025-03-01 이전 데이터만 사용)
cutoff_date = pd.Timestamp("2025-03-01")
weather_df = weather_df[weather_df["acq_date"] <= cutoff_date]
wildfire_df = wildfire_df[wildfire_df["acq_date"] <= cutoff_date]

# 6. 기상 데이터 보간 (클러스터별로 RBF 보간)
# 클러스터 식별을 위해 latitude와 longitude 조합으로 고유 키 생성
weather_df["cluster_id"] = weather_df["latitude"].astype(str) + "_" + weather_df["longitude"].astype(str)

# 보간 전 결측치 확인
print("보간 전 결측치:")
print(weather_df[["T2M", "WS2M", "RH2M", "PRECTOTCORR"]].isnull().sum())

# RBF 보간 적용
weather_vars = ["T2M", "WS2M", "RH2M", "PRECTOTCORR"]
for cluster_id in weather_df["cluster_id"].unique():
    cluster_data = weather_df[weather_df["cluster_id"] == cluster_id].copy()
    if cluster_data[weather_vars].isnull().any().any():
        # 시간 축 (acq_date를 숫자로 변환)
        time_points = (cluster_data["acq_date"] - cluster_data["acq_date"].min()).dt.days.values
        # 결측치가 없는 데이터만 사용
        for var in weather_vars:
            mask = ~cluster_data[var].isnull()
            if mask.sum() > 1:  # 최소 2개 이상의 데이터 포인트 필요
                rbf = RBFInterpolator(
                    time_points[mask].reshape(-1, 1),
                    cluster_data[var][mask],
                    kernel="thin_plate_spline"
                )
                # 결측치가 있는 위치에 대해 보간
                missing_mask = cluster_data[var].isnull()
                if missing_mask.any():
                    interpolated_values = rbf(time_points[missing_mask].reshape(-1, 1))
                    cluster_data.loc[missing_mask, var] = interpolated_values
        # 보간된 데이터로 업데이트
        weather_df.loc[weather_df["cluster_id"] == cluster_id, weather_vars] = cluster_data[weather_vars]

# 보간 후 결측치 확인
print("\nRBF 보간 후 결측치:")
print(weather_df[["T2M", "WS2M", "RH2M", "PRECTOTCORR"]].isnull().sum())

# 7. IDW 보간으로 기상 데이터 매핑
wildfire_df[weather_vars] = wildfire_df.apply(
    lambda row: idw_interpolation(row, weather_df, weather_vars), axis=1
)

# 병합된 데이터프레임 생성
merged_df = wildfire_df.copy()

# 병합 후 결측치 확인 (기상 데이터 매핑 검증)
print("\nIDW 적용 후 결측치:")
print(merged_df[weather_vars].isnull().sum())

# 8. 결측치 처리: 결측치가 있는 행은 선형 보간으로 채우기
for var in weather_vars:
    merged_df[var] = merged_df[var].interpolate(method='linear')

# 결측치 처리 후 확인
print("\n결측치 처리 후 결측치:")
print(merged_df[weather_vars].isnull().sum())

# 9. 2025년 3월 1일 이후 데이터 삭제 (필터링은 이미 적용됨, datetime 생성만 진행)
if "acq_time" in merged_df.columns:
    merged_df["datetime"] = pd.to_datetime(
        merged_df["acq_date"].astype(str) + " " + merged_df["acq_time"].astype(str).str.zfill(4),
        format="%Y-%m-%d %H%M"
    )
else:
    merged_df["datetime"] = merged_df["acq_date"]

# 10. 필요 없는 컬럼 삭제
columns_to_drop = ["acq_time"]
merged_df.drop(columns=columns_to_drop, inplace=True, errors='ignore')

# 11. 결과 출력
print("\n병합된 데이터 정보:")
print(merged_df.info())
print(merged_df.head(5))
# Out:
# 보간 전 결측치:
# T2M            0
# WS2M           0
# RH2M           0
# PRECTOTCORR    0
# dtype: int64
#
# RBF 보간 후 결측치:
# T2M            0
# WS2M           0
# RH2M           0
# PRECTOTCORR    0
# dtype: int64
#
# IDW 적용 후 결측치:
# T2M            0
# WS2M           0
# RH2M           0
# PRECTOTCORR    0
# dtype: int64
#
# 결측치 처리 후 결측치:
# T2M            0
# WS2M           0
# RH2M           0
# PRECTOTCORR    0
# dtype: int64
#
# 병합된 데이터 정보:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1181014 entries, 0 to 1181013
# Data columns (total 19 columns):
#  #   Column       Non-Null Count    Dtype
# ---  ------       --------------    -----
#  0   latitude     1181014 non-null  float32
#  1   longitude    1181014 non-null  float32
#  2   brightness   1181014 non-null  float64
#  3   scan         1181014 non-null  float64
#  4   track        1181014 non-null  float64
#  5   acq_date     1181014 non-null  datetime64[ns]
#  6   satellite    1181014 non-null  object
#  7   instrument   1181014 non-null  object
#  8   confidence   1181014 non-null  object
#  9   version      1181014 non-null  object
#  10  bright_t31   1181014 non-null  float64
#  11  frp          1181014 non-null  float64
#  12  daynight     1181014 non-null  object
#  13  type         1175950 non-null  float64
#  14  T2M          1181014 non-null  float64
#  15  WS2M         1181014 non-null  float64
#  16  RH2M         1181014 non-null  float64
#  17  PRECTOTCORR  1181014 non-null  float64
#  18  datetime     1181014 non-null  datetime64[ns]
# dtypes: datetime64[ns](2), float32(2), float64(10), object(5)
# memory usage: 162.2+ MB
# None
#     latitude   longitude  brightness  scan  track   acq_date satellite  \
# 0 -34.460049  150.887390      337.26  0.42   0.38 2015-01-01         N
# 1 -34.454720  150.876511      336.26  0.42   0.38 2015-01-01         N
# 2 -34.460838  150.882812      342.15  0.42   0.38 2015-01-01         N
# 3 -33.313492  150.622284      332.79  0.42   0.38 2015-01-01         N
# 4 -33.310020  150.621429      338.80  0.42   0.38 2015-01-01         N
#
#   instrument confidence version  bright_t31   frp daynight  type        T2M  \
# 0      VIIRS          n       2      300.09  6.08        D   2.0  23.542729
# 1      VIIRS          n       2      302.46  3.46        D   2.0  23.549633
# 2      VIIRS          n       2      302.23  6.08        D   2.0  23.544854
# 3      VIIRS          n       2      301.44  3.29        D   0.0  25.627192
# 4      VIIRS          n       2      302.00  3.29        D   0.0  25.627632
#
#        WS2M       RH2M  PRECTOTCORR            datetime
# 0  3.046357  77.197443     0.438096 2015-01-01 04:02:00
# 1  3.033239  77.120944     0.437495 2015-01-01 04:02:00
# 2  3.039431  77.155237     0.437809 2015-01-01 04:02:00
# 3  0.431325  61.538323     0.385476 2015-01-01 04:03:00
# 4  0.430816  61.535016     0.385449 2015-01-01 04:03:00

# %%
# 12. 병합된 데이터 저장
merged_df.to_csv("./data/csv/merged_wildfire_weather.csv", index=False)

# %%
# 병합된 데이터 정보 출력
print("\n병합된 데이터 정보:")
print(merged_df.info())

# 데이터 일부 출력 (병합이 제대로 되었는지 확인)
print("\n병합된 데이터 미리보기:")
print(merged_df.head(5))
# Out:
# 병합된 데이터 정보:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1181014 entries, 0 to 1181013
# Data columns (total 19 columns):
#  #   Column       Non-Null Count    Dtype
# ---  ------       --------------    -----
#  0   latitude     1181014 non-null  float32
#  1   longitude    1181014 non-null  float32
#  2   brightness   1181014 non-null  float64
#  3   scan         1181014 non-null  float64
#  4   track        1181014 non-null  float64
#  5   acq_date     1181014 non-null  datetime64[ns]
#  6   satellite    1181014 non-null  object
#  7   instrument   1181014 non-null  object
#  8   confidence   1181014 non-null  object
#  9   version      1181014 non-null  object
#  10  bright_t31   1181014 non-null  float64
#  11  frp          1181014 non-null  float64
#  12  daynight     1181014 non-null  object
#  13  type         1175950 non-null  float64
#  14  T2M          1181014 non-null  float64
#  15  WS2M         1181014 non-null  float64
#  16  RH2M         1181014 non-null  float64
#  17  PRECTOTCORR  1181014 non-null  float64
#  18  datetime     1181014 non-null  datetime64[ns]
# dtypes: datetime64[ns](2), float32(2), float64(10), object(5)
# memory usage: 162.2+ MB
# None
#
# 병합된 데이터 미리보기:
#     latitude   longitude  brightness  scan  track   acq_date satellite  \
# 0 -34.460049  150.887390      337.26  0.42   0.38 2015-01-01         N
# 1 -34.454720  150.876511      336.26  0.42   0.38 2015-01-01         N
# 2 -34.460838  150.882812      342.15  0.42   0.38 2015-01-01         N
# 3 -33.313492  150.622284      332.79  0.42   0.38 2015-01-01         N
# 4 -33.310020  150.621429      338.80  0.42   0.38 2015-01-01         N
#
#   instrument confidence version  bright_t31   frp daynight  type        T2M  \
# 0      VIIRS          n       2      300.09  6.08        D   2.0  23.542729
# 1      VIIRS          n       2      302.46  3.46        D   2.0  23.549633
# 2      VIIRS          n       2      302.23  6.08        D   2.0  23.544854
# 3      VIIRS          n       2      301.44  3.29        D   0.0  25.627192
# 4      VIIRS          n       2      302.00  3.29        D   0.0  25.627632
#
#        WS2M       RH2M  PRECTOTCORR            datetime
# 0  3.046357  77.197443     0.438096 2015-01-01 04:02:00
# 1  3.033239  77.120944     0.437495 2015-01-01 04:02:00
# 2  3.039431  77.155237     0.437809 2015-01-01 04:02:00
# 3  0.431325  61.538323     0.385476 2015-01-01 04:03:00
# 4  0.430816  61.535016     0.385449 2015-01-01 04:03:00

# %%
# 결측치 확인
print("\n병합 후 결측치 확인:")
print(merged_df[weather_vars].isnull().sum())
# Out:
# 병합 후 결측치 확인:
# T2M            0
# WS2M           0
# RH2M           0
# PRECTOTCORR    0
# dtype: int64
